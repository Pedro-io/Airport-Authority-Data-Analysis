# %% [markdown]
# # Análise Inicial do Dados
# Este notebook tem como objetivo a análise do conjunto de dados que será utilizado no projeto

# %%
# importando bibliotecas que seram utilizadas
import pandas as pd 
import os

# %% [markdown]
# ## importando arquivos que seram utilizados

# %%
# Pasta onde as planilhas estão salvas
pasta_planilhas = "C:\\Users\\maype\\Desktop\\projetos\\dados airport" # Caminho das pastas 

# Lista para guardar os dataframes das planilhas 
dataframes = []

# Laço para iterar sobre os arquivos da pasta buscando todos os arquivos csv

for arquivo in os.listdir(pasta_planilhas): 
    if arquivo.endswith(".csv"): 
        # Le o arquivo e cria o dataframe com o pandas
        df = pd.read_csv(os.path.join(pasta_planilhas, arquivo))
        # Adiciona o df a lista
        dataframes.append(df)

# %% [markdown]
# ## Verificando as colunas de cada tabela

# %%
# Verificando quais colunas que existem em cada planilha

colunas = []# Lista para guardar as colunas das planilhas 

# Iterando sobre cada DataFrame e acumulando suas colunas
for planilha in dataframes:
    coluna = planilha.columns 
    colunas.append(coluna)

for i in range(2009, 2019): 
    print("****************************** Colunas referentes ao ano de "+ str(i) +" ******************************")
    for j in range(0, len(coluna)):  # Garante que só itera até o número de colunas disponíveis
        print(coluna[j])
    print("\n")
# Out:
# ****************************** Colunas referentes ao ano de 2009 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27
#
#
# ****************************** Colunas referentes ao ano de 2010 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27
#
#
# ****************************** Colunas referentes ao ano de 2011 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27
#
#
# ****************************** Colunas referentes ao ano de 2012 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27
#
#
# ****************************** Colunas referentes ao ano de 2013 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27
#
#
# ****************************** Colunas referentes ao ano de 2014 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27
#
#
# ****************************** Colunas referentes ao ano de 2015 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27
#
#
# ****************************** Colunas referentes ao ano de 2016 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27
#
#
# ****************************** Colunas referentes ao ano de 2017 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27
#
#
# ****************************** Colunas referentes ao ano de 2018 ******************************
# FL_DATE
# OP_CARRIER
# OP_CARRIER_FL_NUM
# ORIGIN
# DEST
# CRS_DEP_TIME
# DEP_TIME
# DEP_DELAY
# TAXI_OUT
# WHEELS_OFF
# WHEELS_ON
# TAXI_IN
# CRS_ARR_TIME
# ARR_TIME
# ARR_DELAY
# CANCELLED
# CANCELLATION_CODE
# DIVERTED
# CRS_ELAPSED_TIME
# ACTUAL_ELAPSED_TIME
# AIR_TIME
# DISTANCE
# CARRIER_DELAY
# WEATHER_DELAY
# NAS_DELAY
# SECURITY_DELAY
# LATE_AIRCRAFT_DELAY
# Unnamed: 27

# %% [markdown]
# ## Analisando informações gerais sobre cada tabela

# %%
# Iterando sobre os anos de 2009 a 2018
for j in range(0,len(dataframes)):
    anos = ["2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"]
    print("****************************** Análise sobre o dados referentes ao ano de "+ str(anos[j]) +" ******************************")
    print("Informações Gerais sobre o dataframe "+str(anos[j]))
    print(dataframes[j].info())
    print("\n")  # Adiciona uma linha em branco para melhor formatação
# Out:
# ****************************** Análise sobre o dados referentes ao ano de 2009 ******************************
# Informações Gerais sobre o dataframe 2009
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6429338 entries, 0 to 6429337
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 1.3+ GB
# None
#
#
# ****************************** Análise sobre o dados referentes ao ano de 2010 ******************************
# Informações Gerais sobre o dataframe 2010
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6450117 entries, 0 to 6450116
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 1.3+ GB
# None
#
#
# ****************************** Análise sobre o dados referentes ao ano de 2011 ******************************
# Informações Gerais sobre o dataframe 2011
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6066650 entries, 0 to 6066649
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 1.3+ GB
# None
#
#
# ****************************** Análise sobre o dados referentes ao ano de 2012 ******************************
# Informações Gerais sobre o dataframe 2012
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6096762 entries, 0 to 6096761
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         float64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         float64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(22), int64(1), object(5)
# memory usage: 1.3+ GB
# None
#
#
# ****************************** Análise sobre o dados referentes ao ano de 2013 ******************************
# Informações Gerais sobre o dataframe 2013
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6369482 entries, 0 to 6369481
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 1.3+ GB
# None
#
#
# ****************************** Análise sobre o dados referentes ao ano de 2014 ******************************
# Informações Gerais sobre o dataframe 2014
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819811 entries, 0 to 5819810
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 1.2+ GB
# None
#
#
# ****************************** Análise sobre o dados referentes ao ano de 2015 ******************************
# Informações Gerais sobre o dataframe 2015
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 1.2+ GB
# None
#
#
# ****************************** Análise sobre o dados referentes ao ano de 2016 ******************************
# Informações Gerais sobre o dataframe 2016
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5617658 entries, 0 to 5617657
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 1.2+ GB
# None
#
#
# ****************************** Análise sobre o dados referentes ao ano de 2017 ******************************
# Informações Gerais sobre o dataframe 2017
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5674621 entries, 0 to 5674620
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 1.2+ GB
# None
#
#
# ****************************** Análise sobre o dados referentes ao ano de 2018 ******************************
# Informações Gerais sobre o dataframe 2018
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7213446 entries, 0 to 7213445
# Data columns (total 28 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FL_DATE              object
#  1   OP_CARRIER           object
#  2   OP_CARRIER_FL_NUM    int64
#  3   ORIGIN               object
#  4   DEST                 object
#  5   CRS_DEP_TIME         int64
#  6   DEP_TIME             float64
#  7   DEP_DELAY            float64
#  8   TAXI_OUT             float64
#  9   WHEELS_OFF           float64
#  10  WHEELS_ON            float64
#  11  TAXI_IN              float64
#  12  CRS_ARR_TIME         int64
#  13  ARR_TIME             float64
#  14  ARR_DELAY            float64
#  15  CANCELLED            float64
#  16  CANCELLATION_CODE    object
#  17  DIVERTED             float64
#  18  CRS_ELAPSED_TIME     float64
#  19  ACTUAL_ELAPSED_TIME  float64
#  20  AIR_TIME             float64
#  21  DISTANCE             float64
#  22  CARRIER_DELAY        float64
#  23  WEATHER_DELAY        float64
#  24  NAS_DELAY            float64
#  25  SECURITY_DELAY       float64
#  26  LATE_AIRCRAFT_DELAY  float64
#  27  Unnamed: 27          float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 1.5+ GB
# None

# %%
# Iterando sobre os anos de 2009 a 2018
for j in range(0,len(dataframes)):
    anos = ["2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"]
    print("******************************Quantidade de Valores nulos referentes ao ano de "+ str(anos[j]) +" ******************************")
    print("Dados nulos no dataframe "+str(anos[j]))
    print(dataframes[j].isna().sum())
    print("\n")  # Adiciona uma linha em branco para melhor formatação
# Out:
# ******************************Quantidade de Valores nulos referentes ao ano de 2009 ******************************
# Informações Gerais sobre o dataframe 2009
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 0
# DEP_TIME                 82867
# DEP_DELAY                82867
# TAXI_OUT                 85787
# WHEELS_OFF               85787
# WHEELS_ON                89322
# TAXI_IN                  89321
# CRS_ARR_TIME                 0
# ARR_TIME                 89322
# ARR_DELAY               102361
# CANCELLED                    0
# CANCELLATION_CODE      6342300
# DIVERTED                     0
# CRS_ELAPSED_TIME             0
# ACTUAL_ELAPSED_TIME     102362
# AIR_TIME                102361
# DISTANCE                     0
# CARRIER_DELAY          5258837
# WEATHER_DELAY          5258837
# NAS_DELAY              5258837
# SECURITY_DELAY         5258837
# LATE_AIRCRAFT_DELAY    5258837
# Unnamed: 27            6429338
# dtype: int64
#
#
# ******************************Quantidade de Valores nulos referentes ao ano de 2010 ******************************
# Informações Gerais sobre o dataframe 2010
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 0
# DEP_TIME                108777
# DEP_DELAY               108777
# TAXI_OUT                111949
# WHEELS_OFF              111949
# WHEELS_ON               116060
# TAXI_IN                 116060
# CRS_ARR_TIME                 0
# ARR_TIME                116060
# ARR_DELAY               128729
# CANCELLED                    0
# CANCELLATION_CODE      6336862
# DIVERTED                     0
# CRS_ELAPSED_TIME            17
# ACTUAL_ELAPSED_TIME     128729
# AIR_TIME                128729
# DISTANCE                     0
# CARRIER_DELAY          5275233
# WEATHER_DELAY          5275233
# NAS_DELAY              5275233
# SECURITY_DELAY         5275233
# LATE_AIRCRAFT_DELAY    5275233
# Unnamed: 27            6450117
# dtype: int64
#
#
# ******************************Quantidade de Valores nulos referentes ao ano de 2011 ******************************
# Informações Gerais sobre o dataframe 2011
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 0
# DEP_TIME                111699
# DEP_DELAY               111699
# TAXI_OUT                114894
# WHEELS_OFF              114894
# WHEELS_ON               118560
# TAXI_IN                 118560
# CRS_ARR_TIME                 0
# ARR_TIME                118560
# ARR_DELAY               130440
# CANCELLED                    0
# CANCELLATION_CODE      5950614
# DIVERTED                     0
# CRS_ELAPSED_TIME             2
# ACTUAL_ELAPSED_TIME     130440
# AIR_TIME                130440
# DISTANCE                     0
# CARRIER_DELAY          4956119
# WEATHER_DELAY          4956119
# NAS_DELAY              4956119
# SECURITY_DELAY         4956119
# LATE_AIRCRAFT_DELAY    4956119
# Unnamed: 27            6066650
# dtype: int64
#
#
# ******************************Quantidade de Valores nulos referentes ao ano de 2012 ******************************
# Informações Gerais sobre o dataframe 2012
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 1
# DEP_TIME                 75723
# DEP_DELAY                75723
# TAXI_OUT                 77977
# WHEELS_OFF               77977
# WHEELS_ON                80894
# TAXI_IN                  80894
# CRS_ARR_TIME                 2
# ARR_TIME                 80894
# ARR_DELAY                91381
# CANCELLED                    0
# CANCELLATION_CODE      6017900
# DIVERTED                     0
# CRS_ELAPSED_TIME             1
# ACTUAL_ELAPSED_TIME      91381
# AIR_TIME                 91381
# DISTANCE                     0
# CARRIER_DELAY          5081604
# WEATHER_DELAY          5081604
# NAS_DELAY              5081604
# SECURITY_DELAY         5081604
# LATE_AIRCRAFT_DELAY    5081604
# Unnamed: 27            6096762
# dtype: int64
#
#
# ******************************Quantidade de Valores nulos referentes ao ano de 2013 ******************************
# Informações Gerais sobre o dataframe 2013
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 0
# DEP_TIME                 91681
# DEP_DELAY                91681
# TAXI_OUT                 94903
# WHEELS_OFF               94903
# WHEELS_ON                98275
# TAXI_IN                  98275
# CRS_ARR_TIME                 0
# ARR_TIME                 98275
# ARR_DELAY               110172
# CANCELLED                    0
# CANCELLATION_CODE      6273470
# DIVERTED                     0
# CRS_ELAPSED_TIME             5
# ACTUAL_ELAPSED_TIME     110172
# AIR_TIME                110172
# DISTANCE                     0
# CARRIER_DELAY          5100205
# WEATHER_DELAY          5100205
# NAS_DELAY              5100205
# SECURITY_DELAY         5100205
# LATE_AIRCRAFT_DELAY    5100205
# Unnamed: 27            6369482
# dtype: int64
#
#
# ******************************Quantidade de Valores nulos referentes ao ano de 2014 ******************************
# Informações Gerais sobre o dataframe 2014
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 0
# DEP_TIME                122742
# DEP_DELAY               122742
# TAXI_OUT                125951
# WHEELS_OFF              125951
# WHEELS_ON               129628
# TAXI_IN                 129628
# CRS_ARR_TIME                 0
# ARR_TIME                129628
# ARR_DELAY               141433
# CANCELLED                    0
# CANCELLATION_CODE      5692827
# DIVERTED                     0
# CRS_ELAPSED_TIME             6
# ACTUAL_ELAPSED_TIME     141433
# AIR_TIME                141433
# DISTANCE                     0
# CARRIER_DELAY          4579283
# WEATHER_DELAY          4579283
# NAS_DELAY              4579283
# SECURITY_DELAY         4579283
# LATE_AIRCRAFT_DELAY    4579283
# Unnamed: 27            5819811
# dtype: int64
#
#
# ******************************Quantidade de Valores nulos referentes ao ano de 2015 ******************************
# Informações Gerais sobre o dataframe 2015
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 0
# DEP_TIME                 86153
# DEP_DELAY                86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# WHEELS_ON                92513
# TAXI_IN                  92513
# CRS_ARR_TIME                 0
# ARR_TIME                 92513
# ARR_DELAY               105071
# CANCELLED                    0
# CANCELLATION_CODE      5729195
# DIVERTED                     0
# CRS_ELAPSED_TIME             6
# ACTUAL_ELAPSED_TIME     105071
# AIR_TIME                105071
# DISTANCE                     0
# CARRIER_DELAY          4755640
# WEATHER_DELAY          4755640
# NAS_DELAY              4755640
# SECURITY_DELAY         4755640
# LATE_AIRCRAFT_DELAY    4755640
# Unnamed: 27            5819079
# dtype: int64
#
#
# ******************************Quantidade de Valores nulos referentes ao ano de 2016 ******************************
# Informações Gerais sobre o dataframe 2016
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 0
# DEP_TIME                 63456
# DEP_DELAY                63456
# TAXI_OUT                 65418
# WHEELS_OFF               65418
# WHEELS_ON                67844
# TAXI_IN                  67844
# CRS_ARR_TIME                 0
# ARR_TIME                 67844
# ARR_DELAY                79513
# CANCELLED                    0
# CANCELLATION_CODE      5551797
# DIVERTED                     0
# CRS_ELAPSED_TIME             6
# ACTUAL_ELAPSED_TIME      79513
# AIR_TIME                 79513
# DISTANCE                     0
# CARRIER_DELAY          4653419
# WEATHER_DELAY          4653419
# NAS_DELAY              4653419
# SECURITY_DELAY         4653419
# LATE_AIRCRAFT_DELAY    4653419
# Unnamed: 27            5617658
# dtype: int64
#
#
# ******************************Quantidade de Valores nulos referentes ao ano de 2017 ******************************
# Informações Gerais sobre o dataframe 2017
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 0
# DEP_TIME                 80308
# DEP_DELAY                80343
# TAXI_OUT                 82145
# WHEELS_OFF               82141
# WHEELS_ON                84674
# TAXI_IN                  84674
# CRS_ARR_TIME                 0
# ARR_TIME                 84674
# ARR_DELAY                95211
# CANCELLED                    0
# CANCELLATION_CODE      5591928
# DIVERTED                     0
# CRS_ELAPSED_TIME             7
# ACTUAL_ELAPSED_TIME      95211
# AIR_TIME                 95211
# DISTANCE                     0
# CARRIER_DELAY          4645148
# WEATHER_DELAY          4645148
# NAS_DELAY              4645148
# SECURITY_DELAY         4645148
# LATE_AIRCRAFT_DELAY    4645148
# Unnamed: 27            5674621
# dtype: int64
#
#
# ******************************Quantidade de Valores nulos referentes ao ano de 2018 ******************************
# Informações Gerais sobre o dataframe 2018
# FL_DATE                      0
# OP_CARRIER                   0
# OP_CARRIER_FL_NUM            0
# ORIGIN                       0
# DEST                         0
# CRS_DEP_TIME                 0
# DEP_TIME                112317
# DEP_DELAY               117234
# TAXI_OUT                115830
# WHEELS_OFF              115829
# WHEELS_ON               119246
# TAXI_IN                 119246
# CRS_ARR_TIME                 0
# ARR_TIME                119245
# ARR_DELAY               137040
# CANCELLED                    0
# CANCELLATION_CODE      7096862
# DIVERTED                     0
# CRS_ELAPSED_TIME            10
# ACTUAL_ELAPSED_TIME     134442
# AIR_TIME                134442
# DISTANCE                     0
# CARRIER_DELAY          5860736
# WEATHER_DELAY          5860736
# NAS_DELAY              5860736
# SECURITY_DELAY         5860736
# LATE_AIRCRAFT_DELAY    5860736
# Unnamed: 27            7213446
# dtype: int64
